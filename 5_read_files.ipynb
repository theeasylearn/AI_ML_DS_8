# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 3.0.2

# %%
#read csv files
csv = pd.read_csv('marks.csv').squeeze()
print(csv)

# %%
#read excel files
excel = pd.read_excel('marks.xlsx').squeeze()
print(excel)

# %%
#read json  files
json = pd.read_json('marks.json').squeeze()
print(json)
